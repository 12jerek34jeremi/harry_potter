# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils
import matplotlib.pyplot as plt

# %%
utils.prepare_harry_book('data/harry_potter_books/original_txt/format1', 'data/harry_potter_books/prepared_txt', 1)
utils.prepare_harry_book('data/harry_potter_books/original_txt/format2', 'data/harry_potter_books/prepared_txt', 2)
utils.prepare_harry_book('data/harry_potter_books/original_txt/format3', 'data/harry_potter_books/prepared_txt', 3)

# %%
my_dict = utils.create_dictionary('data/harry_potter_books/prepared_txt', 'data/dictionary/second_dictionary_30_04.pickle')

# %%
len(my_dict)
# Out:
# 20950

# %%
my_dict
# Out:
# {'fairground': 0,
#  'glosses': 1,
#  'high-finish': 2,
#  'earner': 3,
#  'descendants': 4,
#  'donate': 5,
#  'bobble': 6,
#  'fidget': 7,
#  'forks': 8,
#  'sirs': 9,
#  'reactions': 10,
#  'shade': 11,
#  'encyclopedia': 12,
#  'aftershave': 13,
#  'slunk': 14,
#  'gosh': 15,
#  'advising': 16,
#  'briefest': 17,
#  'cavort': 18,
#  'free': 19,
#  'allusion': 20,
#  'fog': 21,
#  'ciceron': 22,
#  'swirl': 23,
#  'human-lookin': 24,
#  'comfort': 25,
#  'classmates': 26,
#  'followed': 27,
#  'black-mustached': 28,
#  'botherin': 29,
#  'horseless': 30,
#  'descriptions': 31,
#  'fences': 32,
#  'everpresent': 33,
#  'criminal': 34,
#  'order': 35,
#  'pulsing': 36,
#  'wisp': 37,
#  'unaccountably': 38,
#  'gangly': 39,
#  'jail': 40,
#  'barks': 41,
#  'unconsciously': 42,
#  'experiment': 43,
#  'entrants': 44,
#  'ago': 45,
#  'result': 46,
#  'countless': 47,
#  'run-down': 48,
#  'handiwork': 49,
#  'blackmails': 50,
#  'thunderstorms': 51,
#  'language': 52,
#  'pressed': 53,
#  'puffing': 54,
#  'inferius': 55,
#  'colorless': 56,
#  'woebegone': 57,
#  'repay': 58,
#  'mops': 59,
#  'thorough': 60,
#  'soapsuds': 61,
#  'nancy': 62,
#  'driver': 63,
#  'south': 64,
#  'fibs': 65,
#  'oyt': 66,
#  'drooling': 67,
#  'splattering': 68,
#  'detailed': 69,
#  'jim': 70,
#  'summonses': 71,
#  'shiftily': 72,
#  'caressing': 73,
#  'triangle': 74,
#  'applied': 75,
#  'nooooooooo': 76,
#  'supercool': 77,
#  'shivering': 78,
#  'eyeball': 79,
#  'reusable': 80,
#  'cantered': 81,
#  'shield': 82,
#  'lute': 83,
#  'registry': 84,
#  'brocklehurst': 85,
#  'structured': 86,
#  'alarms': 87,
#  'snapping': 88,
#  'excruciating': 89,
#  'thankfully': 90,
#  'biscuit': 91,
#  'familiar-looking': 92,
#  'irksome': 93,
#  'elbow-length': 94,
#  'ham-like': 95,
#  'nose-biting': 96,
#  'sturgis': 97,
#  'supremely': 98,
#  'steaming': 99,
#  'trolley': 100,
#  'representing': 101,
#  'woefully': 102,
#  'odorless': 103,
#  'thursday': 104,
#  'tuber': 105,
#  'sligh': 106,
#  'gramatica': 107,
#  'research': 108,
#  'engenders': 109,
#  'filch': 110,
#  'eleven': 111,
#  'fores': 112,
#  'bowling': 113,
#  'play': 114,
#  'palominos': 115,
#  'reminisced': 116,
#  'non-tradeable': 117,
#  'pick-me-up': 118,
#  'lessons': 119,
#  'mulish': 120,
#  'suggested': 121,
#  'wrath': 122,
#  'egypt': 123,
#  'bubotuber': 124,
#  'dispute': 125,
#  'consider': 126,
#  "'arry": 127,
#  'supine': 128,
#  'reminiscent': 129,
#  'articles': 130,
#  'thus': 131,
#  'countries': 132,
#  'just-mixed': 133,
#  'vacuum': 134,
#  'side': 135,
#  'distort': 136,
#  'headlined': 137,
#  'late': 138,
#  'reddening': 139,
#  'dutifully': 140,
#  'engulfed': 141,
#  'scarce': 142,
#  'mice': 143,
#  'drag—': 144,
#  'depending': 145,
#  '(': 146,
#  'raffle': 147,
#  'separately': 148,
#  'brethren': 149,
#  'surgically': 150,
#  'weasleys': 151,
#  'beamed': 152,
#  'stupid': 153,
#  'harder': 154,
#  'quelled': 155,
#  'goodness': 156,
#  'nitwit': 157,
#  'distantly': 158,
#  'mosag': 159,
#  'about': 160,
#  'flood': 161,
#  'mundane': 162,
#  'yellowing': 163,
#  'waistlength': 164,
#  'must-not-be-named': 165,
#  'nimbus': 166,
#  'streaking': 167,
#  'bicycles': 168,
#  'appliances': 169,
#  'daydreaming': 170,
#  'muzzle': 171,
#  'spheres': 172,
#  'unacknowledged': 173,
#  'hourglasses': 174,
#  'unmask': 175,
#  'far': 176,
#  'alchemist': 177,
#  'seamlessly': 178,
#  'bilge': 179,
#  'approximately': 180,
#  'obscene': 181,
#  'broom': 182,
#  'lestrange': 183,
#  'unicorn': 184,
#  'ironclad': 185,
#  'linked': 186,
#  'publishing': 187,
#  'event': 188,
#  'panicked': 189,
#  'mickey': 190,
#  'earthy': 191,
#  'cares': 192,
#  'sole': 193,
#  'voluminous': 194,
#  'troy': 195,
#  'advised': 196,
#  'paired': 197,
#  'say': 198,
#  'duffers': 199,
#  'plumage': 200,
#  'colliding': 201,
#  'thoughtfulness': 202,
#  'doris': 203,
#  'seventy-forty': 204,
#  'feature': 205,
#  'safer': 206,
#  'proportion': 207,
#  'miggs': 208,
#  'partnered': 209,
#  'expressions': 210,
#  'incomprehensibly': 211,
#  'submit': 212,
#  'persistent': 213,
#  'wasps': 214,
#  'mischievously': 215,
#  'shocking-pink': 216,
#  'gryff': 217,
#  'wangle': 218,
#  'recognize': 219,
#  'amassed': 220,
#  'infectious': 221,
#  'poorer': 222,
#  'ivanova': 223,
#  'anew': 224,
#  'beeline': 225,
#  'charmed': 226,
#  'thundered': 227,
#  'steered': 228,
#  'jesting': 229,
#  'nosing': 230,
#  'sardinian': 231,
#  'incredulity': 232,
#  'snap': 233,
#  'metallic': 234,
#  'perry': 235,
#  'clap': 236,
#  'motorway': 237,
#  'molly': 238,
#  '89': 239,
#  'emeric': 240,
#  'starve': 241,
#  'dean': 242,
#  'blustering': 243,
#  'desperate': 244,
#  'outpost': 245,
#  'unwisely': 246,
#  'labor': 247,
#  'unravel': 248,
#  'turnaround': 249,
#  'commentators': 250,
#  'he-who-must-not-be-named': 251,
#  'braking': 252,
#  'solved': 253,
#  '125': 254,
#  'bagman.': 255,
#  'amiss': 256,
#  'hisses': 257,
#  'pres': 258,
#  'provoking': 259,
#  'scrolls': 260,
#  'sisters': 261,
#  'outta': 262,
#  'deceive': 263,
#  'knowledgeable': 264,
#  'froglike': 265,
#  'sleepless': 266,
#  'plight': 267,
#  'interference': 268,
#  'pleasure': 269,
#  'drawings': 270,
#  'gasps': 271,
#  'broke': 272,
#  'pages': 273,
#  'non-retaliation': 274,
#  'decanters': 275,
#  "'t": 276,
#  'wailed': 277,
#  'assiduously': 278,
#  'lunar': 279,
#  'stately': 280,
#  'weasley': 281,
#  'leakages': 282,
#  'attire': 283,
#  'attractions': 284,
#  'wont': 285,
#  'honey-colored': 286,
#  'smash': 287,
#  'long-awaited': 288,
#  'horseback': 289,
#  'reinstate': 290,
#  'how': 291,
#  'excruciatingly': 292,
#  'casket': 293,
#  'hoist': 294,
#  'alerting': 295,
#  'grimly': 296,
#  'hoof-shaped': 297,
#  'drawn-out': 298,
#  'deluged': 299,
#  'uni': 300,
#  'drifted': 301,
#  'ganymede': 302,
#  'penalties': 303,
#  'smarting': 304,
#  'maggoty': 305,
#  'fire-blasting': 306,
#  'wheezy': 307,
#  'crinolines': 308,
#  'buses': 309,
#  'venoms': 310,
#  'sponsor': 311,
#  'perish': 312,
#  'stank': 313,
#  'wheedled': 314,
#  'worship': 315,
#  'noise': 316,
#  "'er": 317,
#  'radiated': 318,
#  'bell-covered': 319,
#  'ensnaring': 320,
#  'common': 321,
#  'somber': 322,
#  'impersonating': 323,
#  'off-balance': 324,
#  'sealed': 325,
#  'delacour': 326,
#  'foraging': 327,
#  'leglocker': 328,
#  'twice': 329,
#  'bizarre': 330,
#  'emptier': 331,
#  'ham': 332,
#  'silkily': 333,
#  'sums': 334,
#  'w-what': 335,
#  'buoy': 336,
#  'depends': 337,
#  'ninety-three': 338,
#  'placatingly': 339,
#  'sample': 340,
#  'fool': 341,
#  'exuberant': 342,
#  'dunces': 343,
#  'mercury': 344,
#  'weave': 345,
#  'blinding': 346,
#  'gashes': 347,
#  'engraving': 348,
#  'hacking': 349,
#  'gratitude': 350,
#  'realization': 351,
#  'territory': 352,
#  'extravagant': 353,
#  'myths': 354,
#  'squeaks': 355,
#  'potted-plant': 356,
#  'stow': 357,
#  'stave': 358,
#  'alarmingly': 359,
#  'befouled': 360,
#  'forwards': 361,
#  'room': 362,
#  'subscription': 363,
#  'person': 364,
#  'parks': 365,
#  'rancid': 366,
#  'muttering': 367,
#  'safeguard': 368,
#  'lions': 369,
#  'converged': 370,
#  'matured': 371,
#  'official-looking': 372,
#  'stranded': 373,
#  'ranting': 374,
#  'l-leave': 375,
#  'yaxley': 376,
#  'eased': 377,
#  'focusing': 378,
#  'less-than-friendly': 379,
#  'indestructible': 380,
#  'bethnal': 381,
#  'smack': 382,
#  'program.': 383,
#  'peaked': 384,
#  'visualizing': 385,
#  'hobbling': 386,
#  'graying': 387,
#  'lie': 388,
#  'glummest': 389,
#  'identify': 390,
#  'fish-and-chip': 391,
#  'glistened': 392,
#  'hovel': 393,
#  'snorkack': 394,
#  'delicious': 395,
#  'reignite': 396,
#  'unchallenged': 397,
#  'screamed': 398,
#  'relative': 399,
#  'thirsty': 400,
#  'social': 401,
#  'malkin': 402,
#  'hibernate': 403,
#  'upheld': 404,
#  'shifted': 405,
#  'glamour': 406,
#  'levi-o-sa': 407,
#  'loyalty': 408,
#  'nicknamed': 409,
#  'whomever': 410,
#  'lamplike': 411,
#  'sullens': 412,
#  'maintain': 413,
#  'racing': 414,
#  "'bout": 415,
#  'limp': 416,
#  'inquiry': 417,
#  'vastly': 418,
#  'seemingly': 419,
#  'whooshed': 420,
#  'recruit': 421,
#  'gales': 422,
#  'bulge': 423,
#  'cuffe': 424,
#  'teabag': 425,
#  'precedes': 426,
#  'researches': 427,
#  'sweden': 428,
#  'cramming': 429,
#  'scurvy-grass': 430,
#  'mistaking': 431,
#  'shatter': 432,
#  'unfin-': 433,
#  'great-great-grandson': 434,
#  'packaging': 435,
#  'correspondingly': 436,
#  'tureens': 437,
#  'rockfall': 438,
#  'tunnels': 439,
#  'whale': 440,
#  'tiptoes': 441,
#  'retort': 442,
#  'regarding': 443,
#  'salt': 444,
#  'hungarian': 445,
#  'guffawed': 446,
#  'amidst': 447,
#  'extra-squiggly': 448,
#  'ging': 449,
#  'slurped': 450,
#  'gwenog': 451,
#  'distinctive': 452,
#  'frightened-looking': 453,
#  'stamp': 454,
#  'seduced': 455,
#  'easy-learn': 456,
#  'compounded': 457,
#  'rebounded': 458,
#  'watering': 459,
#  'defined': 460,
#  'eyeing': 461,
#  'imitating': 462,
#  'acidgreen': 463,
#  'amongst': 464,
#  'exceptions': 465,
#  'removal': 466,
#  'eggnog': 467,
#  'doxy-filled': 468,
#  'respectfully': 469,
#  'commuters': 470,
#  'restaurant': 471,
#  'problems': 472,
#  'rafters': 473,
#  'whoops': 474,
#  'blurted': 475,
#  'head.': 476,
#  'rob': 477,
#  'arrested': 478,
#  'startin': 479,
#  'toenails': 480,
#  'seats': 481,
#  'solutions': 482,
#  'besmirching': 483,
#  'anxiouslooking': 484,
#  'assistants': 485,
#  'levicorpus': 486,
#  'detour': 487,
#  'different': 488,
#  'rounding': 489,
#  'ppleased': 490,
#  'tides': 491,
#  'casual': 492,
#  'managing': 493,
#  "'choo": 494,
#  'horcrux': 495,
#  'half-hidden': 496,
#  'kneazles': 497,
#  'incomprehensible': 498,
#  'accident-prone': 499,
#  'algie': 500,
#  'voicing': 501,
#  'invitees': 502,
#  'become': 503,
#  'stopped': 504,
#  'realms': 505,
#  'offering': 506,
#  'foreboding': 507,
#  'written': 508,
#  'dandelion': 509,
#  'vacated': 510,
#  'novices': 511,
#  'stimulants': 512,
#  'fatherly': 513,
#  'descending': 514,
#  'beasts': 515,
#  'crisply': 516,
#  'wet-start': 517,
#  'moi': 518,
#  'location': 519,
#  'clean': 520,
#  'dented': 521,
#  'clutter': 522,
#  'protean': 523,
#  'giants': 524,
#  'booger': 525,
#  'well-publicized': 526,
#  'bubble-gum-pink': 527,
#  'frown': 528,
#  'counterspell': 529,
#  'fen': 530,
#  'shared': 531,
#  'overexcite': 532,
#  'twenty-first': 533,
#  'rereading': 534,
#  'bronze-colored': 535,
#  'dinnertime': 536,
#  't': 537,
#  'sweltering': 538,
#  'lumbered': 539,
#  'nimbly': 540,
#  'lifelong': 541,
#  'hoarse': 542,
#  'allegiance': 543,
#  'tenth': 544,
#  'tournament': 545,
#  'scarf': 546,
#  'puffapod': 547,
#  'unruffled': 548,
#  'matchthe': 549,
#  'firs': 550,
#  'motto': 551,
#  'delaney-podmore': 552,
#  'there': 553,
#  'brass': 554,
#  'recoil': 555,
#  'piece': 556,
#  'sparkle': 557,
#  'glutinous': 558,
#  'postponed': 559,
#  'funny': 560,
#  'rouge': 561,
#  'stolen': 562,
#  'artifacts': 563,
#  'restraining': 564,
#  'sneak': 565,
#  'periwinkle': 566,
#  'pensieve': 567,
#  'sleet-spattered': 568,
#  'odd': 569,
#  'absorbed': 570,
#  'vests': 571,
#  'reopening': 572,
#  'performing': 573,
#  'supposed': 574,
#  'fez': 575,
#  'tomorrow': 576,
#  'embroidered': 577,
#  'thimble': 578,
#  'liberacorpus': 579,
#  'rousing': 580,
#  'rabbits': 581,
#  'analysis': 582,
#  'g-gone': 583,
#  'idea': 584,
#  'state-of-the-art': 585,
#  'constrict': 586,
#  'alleys': 587,
#  'swarms': 588,
#  'tomato-red': 589,
#  'iddum': 590,
#  'prentice': 591,
#  'owl-free': 592,
#  'succulent-looking': 593,
#  'begged': 594,
#  'propping': 595,
#  'flavor': 596,
#  'experiences': 597,
#  'olive-skinned': 598,
#  'overblown': 599,
#  'woolly': 600,
#  'reverence': 601,
#  'fertilizer': 602,
#  'fed': 603,
#  'mentioning': 604,
#  'side-along-apparition': 605,
#  'hoodlums': 606,
#  'sleepy-looking': 607,
#  'messier': 608,
#  'boarded': 609,
#  'aaaaaaarrrgh': 610,
#  'arose': 611,
#  'punishment': 612,
#  'mugglehater': 613,
#  'purple-and-orange': 614,
#  'dentists': 615,
#  'haaa': 616,
#  'seat': 617,
#  'eentup': 618,
#  'traitor': 619,
#  'keyholes': 620,
#  'drain': 621,
#  'icing': 622,
#  'plunging': 623,
#  'ivy': 624,
#  'meaningless': 625,
#  'burned-looking': 626,
#  'constant': 627,
#  'saving-people-thing': 628,
#  'clench': 629,
#  'tear': 630,
#  'detecting': 631,
#  'n.e.w.t.s': 632,
#  'blazing-white': 633,
#  'pinched': 634,
#  'imperius': 635,
#  'abandon': 636,
#  'shadowed': 637,
#  'muggle-hunting': 638,
#  'wool': 639,
#  'budge': 640,
#  'magicked': 641,
#  'buttock': 642,
#  'gamekeeping': 643,
#  'unfortunately': 644,
#  'swearwords': 645,
#  'oversized': 646,
#  'television': 647,
#  'silvery': 648,
#  'ensure': 649,
#  'awkwardness': 650,
#  'backpacks': 651,
#  'affinity': 652,
#  'predictably': 653,
#  'formed': 654,
#  'pervaded': 655,
#  'rub': 656,
#  'soaring': 657,
#  "'ow": 658,
#  'kitchens': 659,
#  'towels': 660,
#  'rescued': 661,
#  'taxis': 662,
#  'hermes': 663,
#  'headin': 664,
#  'chudley': 665,
#  'revised': 666,
#  'troublemakers-inchief': 667,
#  'bending': 668,
#  'grabbing': 669,
#  'learn': 670,
#  'snarl': 671,
#  'hits': 672,
#  'hesitant': 673,
#  'hire': 674,
#  'subcommittee': 675,
#  'st-stuttering': 676,
#  'noooo': 677,
#  'substandard': 678,
#  'yields': 679,
#  'weatherbeaten': 680,
#  'experienced': 681,
#  'grinning': 682,
#  'scalded': 683,
#  'halfway': 684,
#  'wonders': 685,
#  'survives': 686,
#  'borrowed': 687,
#  'chimney': 688,
#  'macho': 689,
#  'fidelius': 690,
#  'strangest': 691,
#  'hardworking': 692,
#  'cinders': 693,
#  'odds-on': 694,
#  'lived': 695,
#  'hinting': 696,
#  'weathered': 697,
#  'seaweed': 698,
#  'heavy-lidded': 699,
#  'ride': 700,
#  'shark-man': 701,
#  'tornados': 702,
#  'spasm': 703,
#  'dismay': 704,
#  'bareness': 705,
#  'flying': 706,
#  'flightless': 707,
#  'bully': 708,
#  'wheedle': 709,
#  'relentless': 710,
#  'narrowly': 711,
#  'dismiss': 712,
#  'lodged': 713,
#  'ecstatically': 714,
#  'dummies': 715,
#  'regulatory': 716,
#  'boots': 717,
#  'spouted': 718,
#  'best-looking': 719,
#  'shone': 720,
#  'subjects': 721,
#  'protest': 722,
#  'things': 723,
#  'banish': 724,
#  'cheekily': 725,
#  'runny': 726,
#  'furled': 727,
#  'disdain': 728,
#  'beauty': 729,
#  'furthermore': 730,
#  'snow-white': 731,
#  'disappear': 732,
#  'moors': 733,
#  'resubmitting': 734,
#  'shrunken': 735,
#  'bristly': 736,
#  'pureblood': 737,
#  'fancied': 738,
#  'stepladder': 739,
#  'spokeswizards': 740,
#  'annotations': 741,
#  'onstage': 742,
#  'licked': 743,
#  'discovery': 744,
#  'stupidly': 745,
#  'grasped': 746,
#  'issuing': 747,
#  'thundery': 748,
#  'male': 749,
#  'rejoice': 750,
#  'aargh': 751,
#  'elephant-man': 752,
#  'thieving': 753,
#  'dumby': 754,
#  'confidentially': 755,
#  'lowhanging': 756,
#  'bramblelike': 757,
#  'grims': 758,
#  'stickman': 759,
#  'd-defense': 760,
#  'whoop': 761,
#  'youngsters': 762,
#  'favors': 763,
#  'battlements': 764,
#  'summat': 765,
#  "'fraid": 766,
#  'hawkshead': 767,
#  'welts': 768,
#  'fevered': 769,
#  'meal': 770,
#  'ant': 771,
#  'ex-head': 772,
#  'prejudiced': 773,
#  'surrounding': 774,
#  'clouds': 775,
#  'publicity': 776,
#  'mutants': 777,
#  'circulation': 778,
#  'takes': 779,
#  'young': 780,
#  'requirements': 781,
#  'put-upon': 782,
#  'babyhood': 783,
#  'darken': 784,
#  'peaky': 785,
#  'complimentin': 786,
#  'shallow': 787,
#  'unhinged': 788,
#  'reduction': 789,
#  'poring': 790,
#  't-t-time': 791,
#  'stretchers': 792,
#  'cleverer': 793,
#  'saves': 794,
#  'fewer': 795,
#  'vot': 796,
#  'eyebrow': 797,
#  'clanged': 798,
#  'historical': 799,
#  'strangest-looking': 800,
#  'velvety': 801,
#  'marginally': 802,
#  'flyingkey': 803,
#  'broadcast': 804,
#  'tha': 805,
#  'contact': 806,
#  'gregorovitch': 807,
#  'd-d-dark': 808,
#  'agreeing': 809,
#  'wide-mouthed': 810,
#  'velvet': 811,
#  'twenty-pound': 812,
#  'advisable': 813,
#  'relation': 814,
#  'ankles': 815,
#  'somersaulting': 816,
#  'rapping': 817,
#  'ousted': 818,
#  'parent': 819,
#  'scuffled': 820,
#  'unemployed': 821,
#  'conspiracy': 822,
#  'retell': 823,
#  'instant': 824,
#  'acquired': 825,
#  'admission': 826,
#  'exasperation': 827,
#  'oh': 828,
#  'blackbound': 829,
#  'residue': 830,
#  'tellings-off': 831,
#  'smears': 832,
#  'grooves': 833,
#  'cross-eyed': 834,
#  'wrong-foot': 835,
#  'promised': 836,
#  'rocket': 837,
#  'strives': 838,
#  'glasses': 839,
#  't-t-to': 840,
#  'differences': 841,
#  'penny': 842,
#  'decades': 843,
#  'looped': 844,
#  'unbecoming': 845,
#  'rallied': 846,
#  'sword': 847,
#  'ribbon': 848,
#  'stanley': 849,
#  'nightshirt': 850,
#  'assassinated': 851,
#  'bewildered-looking': 852,
#  'wanderin': 853,
#  'ladislaw': 854,
#  'tomo': 855,
#  'noble-looking': 856,
#  'satisfaction': 857,
#  'bracelets': 858,
#  'vista': 859,
#  'bugbear': 860,
#  'frayed': 861,
#  'blasts': 862,
#  'genial': 863,
#  'man': 864,
#  'be-': 865,
#  'noisier': 866,
#  'george.': 867,
#  'tenebrus': 868,
#  'pompously': 869,
#  'favorites': 870,
#  "what's-her-name": 871,
#  'fluid': 872,
#  'comics': 873,
#  'once-handsome': 874,
#  'leanne': 875,
#  'tuffets': 876,
#  'responding': 877,
#  'marshal': 878,
#  'spell-checking': 879,
#  'interrogating': 880,
#  'releases': 881,
#  'screwed-up': 882,
#  'braggart': 883,
#  'stews': 884,
#  'mersong': 885,
#  'wandering': 886,
#  'thumping': 887,
#  'reduced': 888,
#  'candlefilled': 889,
#  'locomotor': 890,
#  'harsh': 891,
#  'gibber': 892,
#  'attitudes': 893,
#  'cuffs': 894,
#  'outburst': 895,
#  'marbles': 896,
#  'slept': 897,
#  'outcast': 898,
#  'trampled': 899,
#  'backside': 900,
#  'liquid': 901,
#  'revisiting': 902,
#  'desirable': 903,
#  'dealin': 904,
#  'sores': 905,
#  'cockatrice': 906,
#  'unattended': 907,
#  'guide': 908,
#  'placatory': 909,
#  'end-of-the-holidays': 910,
#  'reassurances': 911,
#  'mill': 912,
#  'vibrate': 913,
#  'chin': 914,
#  'high-backed': 915,
#  'increase': 916,
#  'rubbery': 917,
#  'knickerbockers': 918,
#  'thinkers': 919,
#  'acromantula': 920,
#  'lockets': 921,
#  'anti-dementor': 922,
#  'bumping': 923,
#  'appointment': 924,
#  'loser': 925,
#  'hedwig': 926,
#  'unnaturally': 927,
#  'southward': 928,
#  'dorcas': 929,
#  'underneath': 930,
#  'ripples': 931,
#  'respectable': 932,
#  'n-not': 933,
#  'updated': 934,
#  'urgently': 935,
#  'thunderclap': 936,
#  'supplies': 937,
#  'violent': 938,
#  'saving-peoplething': 939,
#  'aftereffects': 940,
#  'mischief-makers': 941,
#  'wised': 942,
#  'rotate': 943,
#  'defender': 944,
#  'miniscule': 945,
#  'dee-john': 946,
#  'sandwich': 947,
#  'plantes': 948,
#  'permanently': 949,
#  'curly-toed': 950,
#  'apply': 951,
#  'wondering': 952,
#  'vaults': 953,
#  'enclosure': 954,
#  'student': 955,
#  'orrible': 956,
#  'joins': 957,
#  'promptly': 958,
#  'enslaving': 959,
#  'keeper': 960,
#  'waves': 961,
#  'toughness': 962,
#  'climate': 963,
#  'lav-lav': 964,
#  'desert': 965,
#  'goblin-like': 966,
#  'cleaner': 967,
#  'immeasurably': 968,
#  'cannons': 969,
#  'walloped': 970,
#  'disable': 971,
#  'perspective': 972,
#  'declined': 973,
#  'laces': 974,
#  'formally': 975,
#  'funnily': 976,
#  'stammering': 977,
#  'routine': 978,
#  'untransfigure': 979,
#  'tracking': 980,
#  'boggart': 981,
#  'warnings': 982,
#  'powerfully': 983,
#  'culminated': 984,
#  'insufficiently': 985,
#  'baseline': 986,
#  'alighted': 987,
#  'hallmarks': 988,
#  'troubled': 989,
#  'appreciated': 990,
#  'straw-colored': 991,
#  'blowflies': 992,
#  'grassy': 993,
#  'ube': 994,
#  'snarling': 995,
#  '1749': 996,
#  'eye-': 997,
#  'cure': 998,
#  'revisions': 999,
#  ...}

# %%
words1, words2, words3 = utils.words_frequencies('data/harry_potter_books/prepared_txt')

# %%
words1
# Out:
# undertaking        1
# incumbent          1
# oily-haired        1
# dabbling           1
# mid-action         1
#                ...
# ''             30247
# ``             30527
# the            41427
# .              48736
# ,              69911
# Name: frequency, Length: 20950, dtype: Int64

# %%
words2
# Out:
# frequency
# 1        7422
# 2        2812
# 3        1646
# 4        1101
# 5         823
#          ...
# 30247       1
# 30527       1
# 41427       1
# 48736       1
# 69911       1
# Name: words_count, Length: 605, dtype: Int64

# %%
words2.describe()
# Out:
# count     605.000000
# mean       34.628099
# std       336.432608
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         5.000000
# max      7422.000000
# Name: words_count, dtype: float64

# %%
words2[0:6]
# Out:
# frequency
# 1    7422
# 2    2812
# 3    1646
# 4    1101
# 5     823
# 6     616
# Name: words_count, dtype: Int64

# %%
words2[0:6].describe()
# Out:
# count       6.000000
# mean     2403.333333
# std      2581.304451
# min       616.000000
# 25%       892.500000
# 50%      1373.500000
# 75%      2520.500000
# max      7422.000000
# Name: words_count, dtype: float64

# %%
words2[6:20]
# Out:
# frequency
# 7     498
# 8     427
# 9     378
# 10    324
# 11    256
# 12    261
# 13    232
# 14    193
# 15    157
# 16    146
# 17    157
# 18    135
# 19    130
# 20    113
# Name: words_count, dtype: Int64

# %%
words2[6:20].describe()
# Out:
# count     14.000000
# mean     243.357143
# std      121.627810
# min      113.000000
# 25%      148.750000
# 50%      212.500000
# 75%      308.250000
# max      498.000000
# Name: words_count, dtype: float64

# %%
words2[20:150]
# Out:
# frequency
# 21     89
# 22     75
# 23     88
# 24     89
# 25     62
#        ..
# 146     7
# 147     5
# 148     2
# 149     2
# 150     3
# Name: words_count, Length: 130, dtype: Int64

# %%
words2[20:150].describe()
# Out:
# count    130.000000
# mean      18.669231
# std       19.740325
# min        1.000000
# 25%        6.000000
# 50%       10.000000
# 75%       22.000000
# max       89.000000
# Name: words_count, dtype: float64

# %%
words2[150:]
# Out:
# frequency
# 151      2
# 153      6
# 154      3
# 155      3
# 156      4
#         ..
# 30247    1
# 30527    1
# 41427    1
# 48736    1
# 69911    1
# Name: words_count, Length: 455, dtype: Int64

# %%
words2[150:].describe()
# Out:
# count    455.000000
# mean       1.529670
# std        1.091971
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        7.000000
# Name: words_count, dtype: float64

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index, words3, s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[:-20], words3[:-20], s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[-20:], words3[-20:], s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[:250], words3[:250], s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[20:250], words3[20:250], s=3)
plt.show()
