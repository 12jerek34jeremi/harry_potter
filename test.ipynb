# %%
# %load_ext autoreload
# %autoreload 2

# %%
import utils
import matplotlib.pyplot as plt
import pickle
import pandas as pd

# %%
utils.prepare_harry_book('data/harry_potter_books/original_txt/format1', 'data/harry_potter_books/prepared_txt', 1)
utils.prepare_harry_book('data/harry_potter_books/original_txt/format2', 'data/harry_potter_books/prepared_txt', 2)
utils.prepare_harry_book('data/harry_potter_books/original_txt/format3', 'data/harry_potter_books/prepared_txt', 3)

# %%
my_dict = utils.create_dictionary('data/harry_potter_books/prepared_txt', 'data/dictionary/first_dictionary_28_04.pickle')

# %%
len(my_dict)
# Out:
# 23599

# %%
my_dict
# Out:
# {'earner': 0,
#  'mustache': 1,
#  'secrecy.': 2,
#  'wallet': 3,
#  'fly': 4,
#  'peppered': 5,
#  'competitors': 6,
#  'herding': 7,
#  'intently': 8,
#  'purplefaced': 9,
#  'panic.': 10,
#  'apparatus': 11,
#  'skinned': 12,
#  'semiconscious': 13,
#  'commenting': 14,
#  'tantalizing': 15,
#  'beaters': 16,
#  'stare': 17,
#  'recruit': 18,
#  'achievement': 19,
#  'azkaban…': 20,
#  'pearly': 21,
#  'uncoiling': 22,
#  'tottering': 23,
#  'useless…': 24,
#  'receptivity': 25,
#  'funnier': 26,
#  'pulse': 27,
#  'twenty': 28,
#  'swam': 29,
#  'questions.': 30,
#  'wilting': 31,
#  'continued': 32,
#  'mated': 33,
#  'overcoming': 34,
#  'directions': 35,
#  'trauma': 36,
#  'labor.': 37,
#  'noncommittal': 38,
#  'goat': 39,
#  'headship': 40,
#  'swan-shaped': 41,
#  'justify': 42,
#  'footsteps': 43,
#  'incriminating': 44,
#  'part-human': 45,
#  'doxy': 46,
#  'spotted': 47,
#  'adding': 48,
#  'asleep.': 49,
#  'acceptable': 50,
#  'eight-fifteen': 51,
#  'carrots': 52,
#  'attack.': 53,
#  'gobletful': 54,
#  'scrambled': 55,
#  'dormitories': 56,
#  'hoisted': 57,
#  'bloodred': 58,
#  'waited': 59,
#  'reopen': 60,
#  'occlumency': 61,
#  'hospital': 62,
#  'flickering': 63,
#  'terence': 64,
#  'carts.': 65,
#  'will.': 66,
#  'helped.': 67,
#  'hinge': 68,
#  'darker': 69,
#  'horrors': 70,
#  'ominous': 71,
#  'en': 72,
#  'charging': 73,
#  'lem': 74,
#  'pebbles': 75,
#  'hat-stand': 76,
#  'gagged': 77,
#  'sixty-five': 78,
#  'birth': 79,
#  'bad': 80,
#  'begins': 81,
#  'excursion': 82,
#  'vaguest': 83,
#  'instance': 84,
#  'lone': 85,
#  'moonlight.': 86,
#  'sky.': 87,
#  'weirdest': 88,
#  'circular': 89,
#  'needs': 90,
#  'bitterness': 91,
#  'gloomiest': 92,
#  'thud': 93,
#  'lettuce.': 94,
#  'female': 95,
#  'custom': 96,
#  'establish': 97,
#  'sensitive': 98,
#  'vertical': 99,
#  'kitchen.': 100,
#  'curt': 101,
#  'secondhand.': 102,
#  'cords': 103,
#  'two.': 104,
#  'trances': 105,
#  'embroidered': 106,
#  'adverts': 107,
#  'dine': 108,
#  'half-scared': 109,
#  'incarcerous': 110,
#  'meow': 111,
#  'mice': 112,
#  'ems': 113,
#  'unattended': 114,
#  'tear-stained': 115,
#  'd-like-to-see-you-try-it': 116,
#  'boast': 117,
#  'charm.': 118,
#  'tune': 119,
#  'firecracker': 120,
#  'prod': 121,
#  'occlu': 122,
#  'budgerigars': 123,
#  'nudged': 124,
#  'lesson.': 125,
#  'invigoration': 126,
#  'eyelids': 127,
#  'hostage': 128,
#  'dependably': 129,
#  'afraid': 130,
#  'gurgling': 131,
#  'pokery': 132,
#  'g-granger': 133,
#  'adam': 134,
#  'propel': 135,
#  'wince': 136,
#  'apparently': 137,
#  'confused': 138,
#  'ladies…': 139,
#  '—wise': 140,
#  'nostril': 141,
#  'jar': 142,
#  'ol': 143,
#  'phenomenal': 144,
#  'stake…': 145,
#  'aaaaaaand': 146,
#  'settled': 147,
#  'magic…': 148,
#  'unpleasant-looking': 149,
#  'chairwizard': 150,
#  'ploughed': 151,
#  'professor': 152,
#  'steeped': 153,
#  'gringotts': 154,
#  'answered': 155,
#  'stones': 156,
#  'guessed': 157,
#  'ambrosius': 158,
#  'crumpling': 159,
#  'drinks…': 160,
#  'clung': 161,
#  '—': 162,
#  'gingerbread': 163,
#  'stream': 164,
#  'gossamer-fine': 165,
#  'nudge': 166,
#  'rein': 167,
#  'expensive': 168,
#  'sight': 169,
#  'lucky.': 170,
#  'harassedlooking': 171,
#  'correcting': 172,
#  'rack': 173,
#  'commentating': 174,
#  'convert': 175,
#  'eternity': 176,
#  'dusters': 177,
#  'accompanying': 178,
#  'shrunken-looking': 179,
#  'bust': 180,
#  'figments': 181,
#  'snuffs': 182,
#  'sputter': 183,
#  'peacock-feather': 184,
#  'unbolted': 185,
#  'consternation': 186,
#  'dead-looking': 187,
#  'bodies': 188,
#  'gnawed': 189,
#  'pie': 190,
#  'desirous': 191,
#  'taunted': 192,
#  'confiding': 193,
#  'eihwaz.': 194,
#  'parched': 195,
#  'smarten': 196,
#  'hungrily': 197,
#  'wiping': 198,
#  '13': 199,
#  'half-bloods': 200,
#  'intense': 201,
#  'protracted': 202,
#  'jelly': 203,
#  'poker': 204,
#  'fearsome': 205,
#  'subjecting': 206,
#  'blessing': 207,
#  'eenglish': 208,
#  'intimidate': 209,
#  'party': 210,
#  'non-retaliation': 211,
#  'cleverness': 212,
#  'ferocious-looking': 213,
#  'whistlings': 214,
#  'less-than-warm': 215,
#  'tents': 216,
#  'useless': 217,
#  'buries': 218,
#  'brute': 219,
#  'historian': 220,
#  'ireland': 221,
#  'exam': 222,
#  'mazin': 223,
#  'underground…': 224,
#  'ten-foot': 225,
#  'winning': 226,
#  'illustrations': 227,
#  'secretkeeper': 228,
#  'unfrozen': 229,
#  'ferret': 230,
#  'amounted': 231,
#  'reins': 232,
#  'shredded': 233,
#  'knotted': 234,
#  'accelerated': 235,
#  'clunked': 236,
#  'fail-safe': 237,
#  'lawnmower': 238,
#  'flabby': 239,
#  'emptier': 240,
#  'obsessive': 241,
#  'persons': 242,
#  'bag': 243,
#  'accountant': 244,
#  'mouthed': 245,
#  'crashing': 246,
#  'novel': 247,
#  'heaven': 248,
#  'original': 249,
#  'somethin': 250,
#  'mr': 251,
#  'budge': 252,
#  'barring': 253,
#  'anxiety': 254,
#  'hilarity': 255,
#  'kindness': 256,
#  'serious': 257,
#  'silliest': 258,
#  'outside': 259,
#  'gap.': 260,
#  'furnace': 261,
#  'over-shined': 262,
#  'demonstrations': 263,
#  'rednosed': 264,
#  'cleanly': 265,
#  'length': 266,
#  'ivy': 267,
#  'duties.': 268,
#  'uttered': 269,
#  'silver-haired': 270,
#  'execution': 271,
#  'harry-krum-hermione': 272,
#  'sharpest': 273,
#  'eyeholes': 274,
#  'probing': 275,
#  'pur-lease': 276,
#  'trekkin': 277,
#  'idle': 278,
#  'bobbin': 279,
#  'unintentional': 280,
#  'confession': 281,
#  'achieve': 282,
#  'burning': 283,
#  'hoped.': 284,
#  'nosie': 285,
#  'iful': 286,
#  'swapped': 287,
#  'finchfletchley': 288,
#  'first…': 289,
#  'easy.': 290,
#  'toads': 291,
#  'crop': 292,
#  'levi': 293,
#  'continuously': 294,
#  'filtering': 295,
#  'critically': 296,
#  'perhaps': 297,
#  'cafru': 298,
#  'confidence': 299,
#  'gamekeeping': 300,
#  'patterns': 301,
#  'tentacula': 302,
#  'shy': 303,
#  'pink-faced': 304,
#  'popular': 305,
#  'appreciation': 306,
#  'frowning': 307,
#  'haddock': 308,
#  'loosely': 309,
#  'vines': 310,
#  'hives': 311,
#  'fiercely': 312,
#  'contrast': 313,
#  'best.': 314,
#  'tinned': 315,
#  'whiteness': 316,
#  'ruin': 317,
#  'every': 318,
#  'whisperers': 319,
#  'sign': 320,
#  'tide': 321,
#  'mosquitoes': 322,
#  'bareness': 323,
#  'stopping': 324,
#  'whence': 325,
#  'moronic': 326,
#  'waking': 327,
#  'bursts': 328,
#  'dreadlocks': 329,
#  'tactless': 330,
#  'klaxonlike': 331,
#  'teachin': 332,
#  'jinxes': 333,
#  'outsize': 334,
#  'tomato': 335,
#  'wintery': 336,
#  'salesmen': 337,
#  'whalley': 338,
#  'compose': 339,
#  'owing': 340,
#  'lungs': 341,
#  'quidditch-playing': 342,
#  'world-class': 343,
#  'dangers': 344,
#  'all-wizard': 345,
#  'rashes': 346,
#  'worshipped': 347,
#  'sample': 348,
#  'misfortune': 349,
#  'counterpart': 350,
#  'insinuations': 351,
#  'jeering': 352,
#  'prominence': 353,
#  'stalactites': 354,
#  'strengthen': 355,
#  'growin': 356,
#  'jingled': 357,
#  'ouch.': 358,
#  'victory': 359,
#  'involuntary': 360,
#  'believe.': 361,
#  'miracles': 362,
#  'sleet-spattered': 363,
#  'stubbs': 364,
#  'wickedly': 365,
#  'backfiring': 366,
#  'behalf': 367,
#  'wizardwear': 368,
#  'ron…': 369,
#  'inspec': 370,
#  'collected.': 371,
#  'hammered': 372,
#  'congealed': 373,
#  'an': 374,
#  'algie': 375,
#  'speech': 376,
#  'haggle': 377,
#  'glared': 378,
#  'lord.': 379,
#  'me.': 380,
#  'break.': 381,
#  'lanterns': 382,
#  'poisonous-looking': 383,
#  'springy': 384,
#  'three-hundred-and-sixty': 385,
#  'reminded': 386,
#  'hurried': 387,
#  'others': 388,
#  'disapproval': 389,
#  'warring': 390,
#  'punishment': 391,
#  'ordinarily': 392,
#  'grunnings': 393,
#  'flowered': 394,
#  'moaned': 395,
#  'defender': 396,
#  'pals': 397,
#  'feet': 398,
#  'nastier': 399,
#  'cliodna': 400,
#  'intend': 401,
#  'chose': 402,
#  'confine': 403,
#  'mead': 404,
#  'shred': 405,
#  'feelers': 406,
#  'modesty': 407,
#  'lower.': 408,
#  'insists': 409,
#  'unction': 410,
#  'thirty-four': 411,
#  '455': 412,
#  'rag.': 413,
#  'bookcase': 414,
#  'fur': 415,
#  'croakily': 416,
#  'blows': 417,
#  'priceless': 418,
#  'ominously': 419,
#  'all-muggle': 420,
#  'so.': 421,
#  'suitable': 422,
#  'afford.': 423,
#  'obsessing': 424,
#  'magine': 425,
#  'b-b-be': 426,
#  'covert': 427,
#  'furs': 428,
#  'rectify': 429,
#  'peruvian': 430,
#  'roared': 431,
#  'twenty-fourth.': 432,
#  'anapneo': 433,
#  'limbo': 434,
#  'lives…': 435,
#  'suppers': 436,
#  'products.': 437,
#  'rickety': 438,
#  'untarnished': 439,
#  'nerves': 440,
#  'possible.': 441,
#  'manic': 442,
#  'houseguests': 443,
#  'trusting': 444,
#  'fluttering': 445,
#  'groaned': 446,
#  'vanquished': 447,
#  'quietly.': 448,
#  'worthwhile': 449,
#  'automatically': 450,
#  'fingers.': 451,
#  'welsh': 452,
#  'spell.': 453,
#  'reserving': 454,
#  'times': 455,
#  'id': 456,
#  'enmity': 457,
#  'politeness': 458,
#  'bagman': 459,
#  'bulstrode': 460,
#  'jumpy': 461,
#  'lowly': 462,
#  'suffer': 463,
#  'migh': 464,
#  'gushed': 465,
#  'mackintosh': 466,
#  'occurred': 467,
#  'toadless': 468,
#  'albeit': 469,
#  'sleepy': 470,
#  'identity': 471,
#  'aragog.': 472,
#  'pot': 473,
#  'shrinking': 474,
#  'python': 475,
#  'disengaged': 476,
#  'group': 477,
#  'sleeping…': 478,
#  'immediately.': 479,
#  'entrance': 480,
#  'hazily': 481,
#  'lucky': 482,
#  'proceed': 483,
#  'disguised': 484,
#  'nine': 485,
#  'torso': 486,
#  'breakdown': 487,
#  'bowstrings': 488,
#  'massacre': 489,
#  'flat-footed': 490,
#  'complacent': 491,
#  'thronelike': 492,
#  'elephant': 493,
#  'halfhidden': 494,
#  'derisive': 495,
#  'license.': 496,
#  'coconut': 497,
#  'fiddling': 498,
#  'excitement…': 499,
#  'trees': 500,
#  'parent': 501,
#  'scufflings': 502,
#  'appearing': 503,
#  'enlighten': 504,
#  'lamb': 505,
#  'purple-faced': 506,
#  'pus': 507,
#  'tying': 508,
#  'darling.': 509,
#  'stewart': 510,
#  'comforting': 511,
#  'cheerful': 512,
#  'breathing': 513,
#  'horses.': 514,
#  'mock-baby': 515,
#  'littered': 516,
#  'noticing': 517,
#  'treasure.': 518,
#  'few…': 519,
#  'did.': 520,
#  'hairline': 521,
#  'loophole': 522,
#  'big.': 523,
#  'speeding': 524,
#  'whad': 525,
#  'unliftable': 526,
#  'untied': 527,
#  'marketing': 528,
#  'grapes': 529,
#  'campaign': 530,
#  'slit': 531,
#  'flesh-eating': 532,
#  'unprepared': 533,
#  'baby.': 534,
#  'foolproof.': 535,
#  'sneeringly': 536,
#  'frame': 537,
#  'hassan': 538,
#  'owen': 539,
#  'lawns': 540,
#  'details': 541,
#  'unobscured': 542,
#  'lumpy': 543,
#  'throwing': 544,
#  'readiness': 545,
#  'disentangled': 546,
#  'sceptical': 547,
#  'brockdale': 548,
#  'square': 549,
#  'resided': 550,
#  'anti-cheating': 551,
#  'bertha': 552,
#  'schoolmates': 553,
#  'noise.': 554,
#  'armenian': 555,
#  'dundee': 556,
#  'wronski': 557,
#  'baton': 558,
#  'cologne': 559,
#  'unnoticed.': 560,
#  'ginny.': 561,
#  'trickle': 562,
#  'patrollers': 563,
#  'recounted': 564,
#  'murderous': 565,
#  'fastening': 566,
#  'galling': 567,
#  'finch-fletchley': 568,
#  'shore': 569,
#  'flanked': 570,
#  'floaty': 571,
#  'nights': 572,
#  'unseen.': 573,
#  'knuckles': 574,
#  'elephantine': 575,
#  'recipe': 576,
#  'untraceable': 577,
#  'unfin-': 578,
#  'eyeing': 579,
#  'frenzied': 580,
#  'doggy-paddle': 581,
#  'loony': 582,
#  'lost.': 583,
#  'disrepute': 584,
#  'wearier': 585,
#  'sacred': 586,
#  'blistering': 587,
#  'join': 588,
#  'games': 589,
#  'seventeenth': 590,
#  'fights': 591,
#  'blossom': 592,
#  'patient': 593,
#  'gullible.': 594,
#  'disquiet': 595,
#  'pus-filled': 596,
#  'forms': 597,
#  'insider': 598,
#  'holiday': 599,
#  'flyaway': 600,
#  'quaffles': 601,
#  'sealed': 602,
#  'pleased': 603,
#  'booth': 604,
#  'irate': 605,
#  'perchance': 606,
#  'rush': 607,
#  'involvement': 608,
#  'perch': 609,
#  'fifty.': 610,
#  'riffraff': 611,
#  'viated': 612,
#  'pup': 613,
#  'crescent': 614,
#  'galleonsized': 615,
#  'tumultuous': 616,
#  'expensive…': 617,
#  'decade': 618,
#  'progress': 619,
#  'wagged': 620,
#  'sorrier': 621,
#  'scrunched': 622,
#  'heart…': 623,
#  'skipped': 624,
#  'specs': 625,
#  'kindling': 626,
#  'clue.': 627,
#  'money': 628,
#  'celestina': 629,
#  'hug': 630,
#  'constricting': 631,
#  'lads': 632,
#  'cramming': 633,
#  'strolled': 634,
#  'stubs': 635,
#  'accomplishing': 636,
#  'sheltered': 637,
#  'speaks': 638,
#  'strand': 639,
#  'lidded': 640,
#  'attacker': 641,
#  'shooed': 642,
#  'cramped': 643,
#  'arguin': 644,
#  'restores': 645,
#  'appointed': 646,
#  'furiously': 647,
#  'risked': 648,
#  'beaters.': 649,
#  'labeling': 650,
#  'truthfulness': 651,
#  'no…': 652,
#  'letter-thieves': 653,
#  'dusty-looking': 654,
#  'news…': 655,
#  'inhabitants': 656,
#  'arrow': 657,
#  'crinkled': 658,
#  'floor.': 659,
#  'behind.': 660,
#  'paddock': 661,
#  'developed': 662,
#  'menace': 663,
#  'andling': 664,
#  'corks': 665,
#  'great-auntie': 666,
#  'enough…': 667,
#  'dusk-till-dawn': 668,
#  'eyelid': 669,
#  'behavior.': 670,
#  'lie-in.': 671,
#  'protuberant': 672,
#  'pirouetting': 673,
#  'marginally': 674,
#  'poor': 675,
#  'shak-': 676,
#  'bent': 677,
#  'dreading': 678,
#  'skinny': 679,
#  'twenty-one': 680,
#  'regrew': 681,
#  'triggered': 682,
#  'pinching': 683,
#  'yorkshire': 684,
#  'turning': 685,
#  'hers': 686,
#  'post-match': 687,
#  'caution': 688,
#  'hear.': 689,
#  'digesting': 690,
#  'peeler': 691,
#  'blazes': 692,
#  'title': 693,
#  'buttock': 694,
#  'soulfully': 695,
#  'agreed': 696,
#  'erase': 697,
#  'parking': 698,
#  'angrily': 699,
#  'deliberation.': 700,
#  'recoil': 701,
#  '1612–': 702,
#  'brown': 703,
#  'unrested': 704,
#  'sarcasm': 705,
#  'count': 706,
#  'amphitheater': 707,
#  'years': 708,
#  'convinced': 709,
#  'wide…': 710,
#  'frying': 711,
#  'hooked': 712,
#  'occupational': 713,
#  'unfounded': 714,
#  'drop.': 715,
#  'unwitting': 716,
#  'rhinoceros': 717,
#  'stalled': 718,
#  'salmon': 719,
#  'misdemeanors': 720,
#  'twitch': 721,
#  'mischief-makers': 722,
#  'ever.': 723,
#  'morosely': 724,
#  'stringent': 725,
#  'jars': 726,
#  'situation': 727,
#  'inspection': 728,
#  'footstools': 729,
#  'ninety-three': 730,
#  'descend': 731,
#  'behaved': 732,
#  'mingling': 733,
#  'priorities': 734,
#  'clever': 735,
#  'brusquely': 736,
#  'tellings-off': 737,
#  'monday.': 738,
#  'grubby': 739,
#  '(': 740,
#  'pacing': 741,
#  'dumpling': 742,
#  'spends': 743,
#  'sucking': 744,
#  'unpopular…': 745,
#  'sanctuary': 746,
#  'brainwave': 747,
#  'muggle-torture': 748,
#  'clatter': 749,
#  'senior': 750,
#  'wand': 751,
#  'orblike': 752,
#  'mentally': 753,
#  'why': 754,
#  's.p.e.w': 755,
#  'lengthened': 756,
#  'mime': 757,
#  'hairs': 758,
#  'water-skiing': 759,
#  'nurtured': 760,
#  'wearily': 761,
#  'accommodate': 762,
#  'silky': 763,
#  'willow.': 764,
#  'froth': 765,
#  'learn…': 766,
#  'gulps': 767,
#  'cuffing': 768,
#  'i74i–i768': 769,
#  'brainy': 770,
#  'entertaining.': 771,
#  'playing': 772,
#  'embrace': 773,
#  'revisiting': 774,
#  'awfully': 775,
#  'voldemort.': 776,
#  'wring': 777,
#  'another.': 778,
#  'dudley…': 779,
#  'bin.': 780,
#  'sailing': 781,
#  'simpered': 782,
#  'monkey': 783,
#  'swelling': 784,
#  'violent': 785,
#  'phantom': 786,
#  'thistles': 787,
#  'soot-blackened': 788,
#  'yellowing': 789,
#  'mutinously': 790,
#  'wheeled': 791,
#  'weekly.': 792,
#  'kirke': 793,
#  'paranoid': 794,
#  'too-small': 795,
#  'smattered': 796,
#  'friend.': 797,
#  'sparingly': 798,
#  'sprays': 799,
#  'advice.': 800,
#  'unemployed.': 801,
#  'guffawing': 802,
#  'murdered.': 803,
#  'down-toearth': 804,
#  'yolk': 805,
#  'social': 806,
#  'dejected': 807,
#  'hippo…': 808,
#  'foot-and-a-half-long': 809,
#  'hydrangea': 810,
#  'toes': 811,
#  'roughly': 812,
#  'punching': 813,
#  'tattoo': 814,
#  'leviosa': 815,
#  'greeting': 816,
#  'keeled': 817,
#  'is.': 818,
#  'ages.': 819,
#  'night': 820,
#  'miniature': 821,
#  'crushing': 822,
#  'informative': 823,
#  '—do': 824,
#  'across…': 825,
#  'yeti': 826,
#  'goulash': 827,
#  'guts': 828,
#  'helmet': 829,
#  'confuse': 830,
#  'too.': 831,
#  'leaky': 832,
#  'huddle': 833,
#  'counterbalance': 834,
#  'engagement': 835,
#  'sickles': 836,
#  'socks': 837,
#  'gift': 838,
#  'disturbed': 839,
#  'engulf': 840,
#  'stacked': 841,
#  'any': 842,
#  'lacewings': 843,
#  'aids': 844,
#  'drinks': 845,
#  'deep-green': 846,
#  'peanuts': 847,
#  'activity': 848,
#  'mullet': 849,
#  'black-bodied': 850,
#  'grawp': 851,
#  'easier.': 852,
#  'slanting': 853,
#  'on-the-spot': 854,
#  'townsfolk': 855,
#  'flume': 856,
#  'confused.': 857,
#  'exist': 858,
#  'destined': 859,
#  'restaurants': 860,
#  'hoodwinked': 861,
#  'mighty': 862,
#  'tongue': 863,
#  'icily': 864,
#  'hunchbacked': 865,
#  'confetti': 866,
#  'wattlebird': 867,
#  'droppings': 868,
#  'shortly': 869,
#  'wiped': 870,
#  'puppeteers': 871,
#  'height': 872,
#  'by-the-by': 873,
#  'peppering': 874,
#  'down.': 875,
#  'cows': 876,
#  'doors': 877,
#  'shell-less': 878,
#  'barrel': 879,
#  'observations': 880,
#  'peppermint': 881,
#  'brat': 882,
#  'irons': 883,
#  'fell': 884,
#  'hibernate': 885,
#  's-swear': 886,
#  'jammed': 887,
#  'sharpish': 888,
#  'frock': 889,
#  'colorful': 890,
#  'earlobes': 891,
#  'benefit': 892,
#  'episode': 893,
#  'dreamlike': 894,
#  'sagged': 895,
#  'variously': 896,
#  'de-doxying': 897,
#  'prised': 898,
#  'swallowing': 899,
#  'miffed': 900,
#  'mirror…': 901,
#  'sighted': 902,
#  'healer-in-charge': 903,
#  'extremities': 904,
#  'mundanely': 905,
#  'chairs': 906,
#  'memorable': 907,
#  'by-products': 908,
#  'governing': 909,
#  'howard': 910,
#  'unceremoniously': 911,
#  'clotted': 912,
#  'sentinel': 913,
#  'confiscation': 914,
#  'axebanger': 915,
#  'cooperation': 916,
#  'b.': 917,
#  'willingly': 918,
#  '.let': 919,
#  'unfurled': 920,
#  'repeated': 921,
#  'joey': 922,
#  'finch-': 923,
#  'procession': 924,
#  'poorer': 925,
#  'vacant': 926,
#  'currant-colored': 927,
#  'belting': 928,
#  'oak': 929,
#  'careening': 930,
#  'black-and-purple': 931,
#  'breeding': 932,
#  'dressed': 933,
#  'beheading': 934,
#  'habitat': 935,
#  'coulda': 936,
#  'exchequer': 937,
#  'greasily': 938,
#  'downward': 939,
#  'well-fed': 940,
#  'promptings': 941,
#  'lute': 942,
#  'us': 943,
#  'tears…': 944,
#  'trimming': 945,
#  'pretence': 946,
#  'slightly.': 947,
#  'twas': 948,
#  'rushing': 949,
#  'blooming': 950,
#  'blood-replenishing': 951,
#  'childhood': 952,
#  'consistency': 953,
#  'stool': 954,
#  'heel': 955,
#  'steal': 956,
#  'both.': 957,
#  'tiptoeing': 958,
#  'conjuring': 959,
#  'foe.': 960,
#  'ridiculously': 961,
#  'sojourn': 962,
#  'mer-idiots': 963,
#  'thong': 964,
#  'first-floor': 965,
#  'maternal': 966,
#  'fidgeting': 967,
#  'mouth.': 968,
#  'fantastic': 969,
#  'impeded': 970,
#  'george': 971,
#  'fun': 972,
#  'slowly': 973,
#  'induct': 974,
#  'calculated': 975,
#  'gurdyroot': 976,
#  'ours.': 977,
#  'brutally': 978,
#  'hogwarts…': 979,
#  'well-being': 980,
#  'ones': 981,
#  'mislabelled': 982,
#  'f': 983,
#  'reporting.': 984,
#  'second-rater': 985,
#  'myths': 986,
#  'vill': 987,
#  'thunderclap': 988,
#  'scrutinizing': 989,
#  'puffing': 990,
#  'mightily': 991,
#  'blustering': 992,
#  'daphne': 993,
#  'allusion': 994,
#  'clenching': 995,
#  'm-magic': 996,
#  'counts': 997,
#  'asperity': 998,
#  'exercising': 999,
#  ...}

# %%
words1, words2, words3 = utils.words_frequencies('data/harry_potter_books/prepared_txt')

# %%
words1
# Out:
# hollow.          1
# despoiled        1
# long-dead        1
# jug-eared        1
# lamppost         1
#              ...
# ”            30259
# “            30510
# the          41436
# .            61121
# ,            69922
# Name: frequency, Length: 23599, dtype: Int64

# %%
words2
# Out:
# frequency
# 1        9144
# 2        3201
# 3        1830
# 4        1203
# 5         884
#          ...
# 30259       1
# 30510       1
# 41436       1
# 61121       1
# 69922       1
# Name: words_count, Length: 607, dtype: Int64

# %%
words2.describe()
# Out:
# count     607.000000
# mean       38.878089
# std       406.548360
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         4.000000
# max      9144.000000
# Name: words_count, dtype: float64

# %%
words2[0:6]
# Out:
# frequency
# 1    9144
# 2    3201
# 3    1830
# 4    1203
# 5     884
# 6     659
# Name: words_count, dtype: Int64

# %%
words2[0:6].describe()
# Out:
# count       6.000000
# mean     2820.166667
# std      3229.580246
# min       659.000000
# 25%       963.750000
# 50%      1516.500000
# 75%      2858.250000
# max      9144.000000
# Name: words_count, dtype: float64

# %%
words2[6:25]
# Out:
# frequency
# 7     519
# 8     439
# 9     403
# 10    343
# 11    272
# 12    281
# 13    228
# 14    191
# 15    152
# 16    155
# 17    166
# 18    139
# 19    130
# 20    115
# 21     89
# 22     80
# 23     81
# 24     92
# 25     72
# Name: words_count, dtype: Int64

# %%
words2[6:25].describe()
# Out:
# count     19.000000
# mean     207.736842
# std      133.806179
# min       72.000000
# 25%      103.500000
# 50%      155.000000
# 75%      276.500000
# max      519.000000
# Name: words_count, dtype: float64

# %%
words2[25:150]
# Out:
# frequency
# 26     77
# 27     77
# 28     67
# 29     46
# 30     51
#        ..
# 146     5
# 147     3
# 148     6
# 150     6
# 151     4
# Name: words_count, Length: 125, dtype: Int64

# %%
words2[25:150].describe()
# Out:
# count    125.000000
# mean      16.336000
# std       15.561503
# min        2.000000
# 25%        6.000000
# 50%       11.000000
# 75%       22.000000
# max       77.000000
# Name: words_count, dtype: float64

# %%
words2[150:]
# Out:
# frequency
# 152      5
# 153      5
# 154      3
# 156      7
# 157      4
#         ..
# 30259    1
# 30510    1
# 41436    1
# 61121    1
# 69922    1
# Name: words_count, Length: 457, dtype: Int64

# %%
words2[150:].describe()
# Out:
# count    457.000000
# mean       1.507659
# std        1.043172
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        7.000000
# Name: words_count, dtype: float64

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index, words3, s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[:-20], words3[:-20], s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[-20:], words3[-20:], s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[:250], words3[:250], s=3)
plt.show()

# %%
# %matplotlib inline
f = plt.figure(figsize=(25, 12))
plt.scatter(words3.index[20:250], words3[20:250], s=3)
plt.show()
